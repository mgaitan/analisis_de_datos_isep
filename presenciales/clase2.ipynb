# %% [markdown]
# # Clase presencial Nº 2

# %% [markdown]
# ## Algunos Portales de datos abiertos de Gobiernos

# %%
from IPython.display import IFrame
IFrame("http://datos.gob.ar/", width="100%", height="600px")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="http://datos.gob.ar/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame("http://datos.gba.gob.ar/", width="100%", height="600px")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="http://datos.gba.gob.ar/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# También está el de la [ciudad de Córdoba](https://gobiernoabierto.cordoba.gob.ar/data/datos-abiertos)  y [muchísimos más](https://www.opendatasoft.com/a-comprehensive-list-of-all-open-data-portals-around-the-world)

# %%
import pandas as pd

desempleo_barcelona_2016 = pd.read_csv('http://opendata-ajuntament.barcelona.cat/data/dataset/7f78b62c-ae97-49cf-8e58-d746b0ffb2a3/resource/5711ffb8-6f4e-4e74-8e8d-7f7219b0ac70/download/2016_evopercent2016.csv', decimal=',', encoding='latin1')
desempleo_barcelona_2016.head()
# Out:
#    Dte.                                    Barris Població\n16-64 anys  Gener  \
# 0     1                               1. el Raval               35.173   11.3
# 1     1                         2. el Barri Gòtic               12.088    8.7
# 2     1                         3. la Barceloneta               10.802   11.3
# 3     1  4. Sant Pere, Santa Caterina i la Ribera               16.757   10.1
# 4     2                          5. el Fort Pienc               20.956    7.1
#
#    Febrer  Març  Abril  Maig  Juny  Juliol  Agost  Setembre  Octubre  \
# 0    11.2  11.2   11.0  10.3  10.1     9.9    9.7       9.9      9.9
# 1     8.5   8.3    8.0   7.6   7.3     7.2    7.1       7.2      7.2
# 2    10.9  10.8   10.5  10.1   9.7     9.6    9.8       9.8      9.9
# 3     9.7   9.6    9.4   9.0   8.7     8.6    8.8       8.8      8.8
# 4     6.9   6.8    6.6   6.4   6.2     6.1    6.3       6.3      6.4
#
#    Novembre  Desembre
# 0      10.2      10.1
# 1       7.5       7.5
# 2      10.0       9.9
# 3       8.9       8.8
# 4       6.4       6.4

# %%
# %matplotlib inline
ax = desempleo_barcelona_2016.iloc[0][3:].plot.line()
ax.set_title('Desempleo en Barrio {} de Barcelona durante 2016'.format(desempleo_barcelona_2016.loc[0, 'Barris']))

# %% [markdown]
# Pero otros portales no tiene **datos abiertos** (de calidad)
#
# Ejemplo:

# %%
IFrame('http://www.justiciacordoba.gob.ar/transparencia/', width="100%", height="600px")
# Out:
#         <iframe
#             width="100%"
#             height="600px"
#             src="http://www.justiciacordoba.gob.ar/transparencia/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Recomiendo leer sobre las clasificaciones sobre las "[5 estrellas]('http://opendata-ajuntament.barcelona.cat/es/faqs/#collapseEighteen)" de los datos abiertos

# %% [markdown]
# ## Y ahora analicemos la inflación de mayo

# %%
precios_abril = pd.read_csv('../proyecto_integrador/precios_2018-04-20.csv')
precios_abril.head()
# Out:
#     sucursal    producto_id  precio
# 0  11-5-1010  7790080065343   18.99
# 1  11-5-1010  7791337910423   22.99
# 2  11-5-1010  7790787110513   15.40
# 3  11-5-1010  7791337910416   22.99
# 4  11-5-1010  7790080068498   25.59

# %%
precios_mayo = pd.read_csv('../proyecto_integrador/precios_2018-05-15.csv')
precios_mayo.head()
# Out:
#   sucursal    producto_id  precio
# 0   14-1-6  7790080065121    22.9
# 1   14-1-6  7790080065190    19.5
# 2   14-1-6  7791337601215    14.5
# 3   14-1-6  7791337690813    33.9
# 4   14-1-6  7791337695719    33.9

# %%
sucursales = pd.read_csv('../proyecto_integrador/sucursales.csv')
sucursales.head()
# Out:
#      localidad      sucursalNombre                     direccion  \
# 0  Alta Gracia         Sucursal 07             Av. Sarmiento 618
# 1  Alta Gracia         Sucursal 06           Consejal Alonso 770
# 2  Alta Gracia         Sucursal 04          Lucas V. Cordoba 965
# 3   Alto Verde  Córdoba Granaderos        Bvard. Granaderos 2906
# 4     ARGUELLO    CORDOBA ARGUELLO  Avenida Recta Martinoli 5981
#
#    sucursalTipo        lat        lng  sucursalId  comercioId  banderaId  \
# 0  Supermercado -31.654088 -64.442259           7          14          1
# 1  Autoservicio -31.664987 -64.427644           6          14          1
# 2  Supermercado -31.648480 -64.433943           4          14          1
# 3  Supermercado -31.374529 -64.213855         295          10          2
# 4  Autoservicio -31.350300 -64.251650        2101          19          1
#
#           id
# 0     14-1-7
# 1     14-1-6
# 2     14-1-4
# 3   10-2-295
# 4  19-1-2101

# %%
cadenas = pd.read_csv('../proyecto_integrador/cadenas.csv')
cadenas.head()
# Out:
#    comercioId  banderaId          comercioRazonSocial    banderaDescripcion
# 0           9          2  Jumbo Retail Argentina S.A.                 Disco
# 1           9          3  Jumbo Retail Argentina S.A.                 Jumbo
# 2           9          1  Jumbo Retail Argentina S.A.                   Vea
# 3          11          5    Wal Mart Argentina S.R.L.   Walmart SuperCenter
# 4          11          1    Wal Mart Argentina S.R.L.  Walmart Supermercado

# %%
productos = pd.read_csv('../proyecto_integrador/productos.csv')
productos.head()
# Out:
#                                               nombre       marca  \
# 0  Yogur Entero Firme Frutado Multinutrientes San...        YOGS
# 1  Yogur Entero Firme Frutilla Sancor Yogs Pack 2...        YOGS
# 2      Yogur Entero Firme Frutilla Yogurisimo 190 Gr  YOGURISIMO
# 3  Yogur Entero Firme Frutilla Yogurisimo 4 Un 50...  YOGURISIMO
# 4  Yogur Entero Firme Multinutrientes Frambuesa M...        YOGS
#
#               id presentacion
# 0  7790080065107     180.0 gr
# 1  7790080065183     250.0 gr
# 2  7791337651227     190.0 gr
# 3  7791337690820     500.0 gr
# 4  7790080065121     180.0 gr

# %%
precios = pd.merge(precios_abril, precios_mayo, on=['sucursal', 'producto_id'])
precios.head()
# Out:
#   sucursal    producto_id  precio_x  precio_y
# 0   14-1-6  7790080065121      22.9      22.9
# 1   14-1-6  7790080065190      19.5      19.5
# 2   14-1-6  7791337601215      14.5      14.5
# 3   14-1-6  7791337690813      33.9      33.9
# 4   14-1-6  7791337695719      33.9      33.9

# %%
precios = pd.merge(precios_abril, precios_mayo, on=['sucursal', 'producto_id'], suffixes=('_abril', '_mayo'))
precios.head()
# Out:
#   sucursal    producto_id  precio_abril  precio_mayo
# 0   14-1-6  7790080065121          22.9         22.9
# 1   14-1-6  7790080065190          19.5         19.5
# 2   14-1-6  7791337601215          14.5         14.5
# 3   14-1-6  7791337690813          33.9         33.9
# 4   14-1-6  7791337695719          33.9         33.9

# %%
precios['aumento'] = (precios['precio_mayo'] - precios['precio_abril']) * 100 / precios['precio_abril']
precios.head()
# Out:
#   sucursal    producto_id  precio_abril  precio_mayo  aumento
